# %%
import pandas as pd
import argparse
import random
import time
import os
import duckdb
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram, leaves_list
from sklearn.cluster import KMeans
# %matplotlib inline
import sys
sys.path.append(os.path.abspath(os.getcwd()+'/..'))

from crptmidfreq.config_loc import get_data_db_folder
from crptmidfreq.featurelib.lib_v1 import *
from crptmidfreq.res.visualize_pairs.data_cleaning import get_pivoted_data

plt.style.use('ggplot')


g_folder = 'res_exploration_v1'
# Out:
# /Users/sachadrevet/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
def analyze_pair(t1='BTCUSDT',t2='ETHUSDT'):
    pdf = get_pivoted_data(tokens=[t1,t2])
    corr = pdf[[t1,t2]].corr()
    plt.figure()
    pdf[[t1,t2]].fillna(0.0).cumsum().plot()
    plt.figure()
    sns.regplot(data=pdf[[t1,t2]].fillna(0.0),x=t1,y=t2)
    print(f'Correl of {corr}')

# %%
analyze_pair(t1='BTCUSDT',t2='ETHUSDT')
# Out:
# Reading data from DuckDB
# Cleaning data
# Stepper creating instance res_kmeans_v1 None_close_diff1
# Stepper creating instance res_kmeans_v1 None_tret_clip
# Stepper creating instance res_kmeans_v1 None_volume_ewm1000
# Stepper creating instance res_kmeans_v1 None_pivot_tret
# pivot_start
# pivot_end
# Correl of           BTCUSDT   ETHUSDT
# BTCUSDT  1.000000  0.818093
# ETHUSDT  0.818093  1.000000

# %%
analyze_pair(t1='COMBOUSDT',t2='ETHUSDT')
# Out:
# Reading data from DuckDB
# Cleaning data
# Stepper creating instance res_kmeans_v1 None_close_diff1
# Stepper creating instance res_kmeans_v1 None_tret_clip
# Stepper creating instance res_kmeans_v1 None_volume_ewm1000
# Stepper creating instance res_kmeans_v1 None_pivot_tret
# pivot_start
# pivot_end
# Correl of            COMBOUSDT  ETHUSDT
# COMBOUSDT     1.0000   0.3646
# ETHUSDT       0.3646   1.0000

# %%
analyze_pair(t1='VVVUSDT',t2='ETHUSDT')
# Out:
# Reading data from DuckDB
# Cleaning data
# Stepper creating instance res_kmeans_v1 None_close_diff1
# Stepper creating instance res_kmeans_v1 None_tret_clip
# Stepper creating instance res_kmeans_v1 None_volume_ewm1000
# Stepper creating instance res_kmeans_v1 None_pivot_tret
# pivot_start
# pivot_end
# Correl of           VVVUSDT   ETHUSDT
# VVVUSDT  1.000000  0.117298
# ETHUSDT  0.117298  1.000000

# %%
analyze_pair(t1='ARBUSDT',t2='ETHUSDT')
# Out:
# Reading data from DuckDB
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Cleaning data
# Stepper creating instance res_kmeans_v1 None_close_diff1
# Stepper creating instance res_kmeans_v1 None_tret_clip
# Stepper creating instance res_kmeans_v1 None_volume_ewm1000
# Stepper creating instance res_kmeans_v1 None_pivot_tret
# pivot_start
# pivot_end

# %%
analyze_pair(t1='DEGOUSDT',t2='ETHUSDT')

# %%
analyze_pair(t1='BNBUSDT',t2='ETHUSDT')

# %%
analyze_pair(t1='BNBUSDT',t2='BNXUSDT')
