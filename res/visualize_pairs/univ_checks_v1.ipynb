# %%
import pandas as pd
import argparse
import random
import time
import os
import duckdb
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from crptmidfreq.utils.common import to_csv

from crptmidfreq.config_loc import get_data_db_folder
from crptmidfreq.config_loc import get_analysis_folder

from crptmidfreq.res.visualize_pairs.data_cleaning import get_univ_cnt

g_folder = 'res_kmeans_v1'

# %%
dfu=get_univ_cnt(sdate_str='2019-01-01')
# Out:
# Reading data from DuckDB
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Please open :/Users/sachadrevet/data_tmp/analysis/univ_cnt.csv

# %%
dfu.set_index('trade_date').sort_index()['unique_dscode_count'].plot(title='Binance available universe')
# Out:
# <Axes: title={'center': 'Binance available universe'}, xlabel='trade_date'>
